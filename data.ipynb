# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
startupp=df[df['Startup Name']=='Swiggy'][['Date','Startup Name','Industry Vertical','City','Investors Name','Investment Type','amount']]
startupp.rename(columns={'Investment Type':'Round','amount':'Amount in Cr'},inplace=True)

# %%
startupp
# Out:
#             Date Startup Name     Industry Vertical       City  \
# 0     03-04-2015       Swiggy  Online Food Delivery  Bangalore
# 72    06-05-2015       Swiggy  Online Food Delivery  Bangalore
# 147   09-06-2015       Swiggy  Online Food Ordering  Bangalore
# 810   19-01-2016       Swiggy     Consumer Internet  Bangalore
# 1145  10-05-2016       Swiggy     Consumer Internet  Bangalore
# 1482  19-09-2016       Swiggy     Consumer Internet  Bangalore
# 2064  30-05-2017       Swiggy     Consumer Internet  Bangalore
# 2465  07-02-2018       Swiggy    Food and Beverages  Bengaluru
#
#                                          Investors Name           Round  \
# 0                         Accel Partners, SAIF Partners  Private Equity
# 72                             Norwest Venture Partners  Private Equity
# 147   Norwest Venture Partners, SAIF Partners, Accel...  Private Equity
# 810   Harmony Partners, RB Investments & existing in...  Private Equity
# ...

# %%
swiggy=startupp[startupp['Startup Name']=='Swiggy'].groupby('Date')['Amount in Cr'].max().sort_values(ascending=False).head()
plt.bar(swiggy.index,swiggy.values)
swiggy.index
# swiggy.values
# Out:
# Index(['07-02-2018', '30-05-2017', '19-01-2016', '09-06-2015', '06-05-2015'], dtype='object', name='Date')

# %%
a=startupp.groupby('Date')['Amount in Cr'].max().sort_values(ascending=False).head()
# Out:
# array([860. , 688. , 301. , 141.9, 129. ])

# %%
df=pd.read_csv('C:/Users/shahi/OneDrive/Desktop/Seminar/dashboard_stremlit/cleaned_startup./')
df
# Out:
#             Date Startup Name       Industry Vertical  \
# 0     03-04-2015       Swiggy    Online Food Delivery
# 1     04-04-2015     Bluegape  Web Content Publishing
# 2     06-04-2015  InstaLively         Video Streaming
# 3     07-04-2015     LogiNext          Logistics Tech
# 4     07-04-2015    PressPlay    Travel Entertainment
# ...          ...          ...                     ...
# 2823  09-01-2020        BYJUS                  E-Tech
# 2824  09-01-2020    Mamaearth              E-commerce
# 2825  10-01-2020       Zomato             Hospitality
# 2826  13-01-2020        Pando               Logistics
# 2827  13-01-2020       Shuttl          Transportation
#
#                                    SubVertical       City  \
# 0                                          NaN  Bangalore
# 1                                          NaN    Gurgaon
# 2                                          NaN  New Delhi
# 3                                          NaN     Mumbai
# ...

# %%
sorted(df['Startup Name'].unique().tolist())
# Out:
# ['121Policy',
#  '19th mile',
#  '1Crowd',
#  '1mg',
#  '1mg (Healthkartplus)',
#  '20Dresses',
#  '33Coupons',
#  '360Ride',
#  '3Dexter',
#  '3HCare',
#  '3rdFlix',
#  '48East',
#  '4tigo',
#  '5th Vital',
#  '6Degree',
#  '75F',
#  '91SpringBoard',
#  '99Games',
#  '99PerHour',
#  '9Stacks',
#  'A&R Bon Vivants',
#  'ABI Health',
#  'AEON Learning',
#  'AHA Taxis',
#  'AYE Finance',
#  'AadharAPI.com',
#  'Aadyah',
#  'Aahaa',
#  'Aahaa Stores',
#  'Aarav UAV',
#  'Aasaanjobs',
#  'Aashiyaan',
#  'Aavishkaar-Intellecap Group',
#  'AbeRuk',
#  'Abhibus',
#  'Absentia',
#  'Absentia VR',
#  'Ace Turtle',
#  'Ace2three',
#  'Acko',
#  'ActOnMagic',
#  'Actionable Analytics',
#  'Active AI',
#  'Active.ai',
#  'Actofit',
#  'Ad2pro',
#  'AdPushUp',
#  'AdStringO',
#  'AdUrCup',
#  'AdWyze',
#  'Address Health',
#  'AdmitKard',
#  'Advanced Structures India',
#  'Advantage Club',
#  'Advenio',
#  'Adytude',
#  'Aequm',
#  'AerMed',
#  'Affimity',
#  'Affordplan',
#  'Agara Labs',
# ...

# %%
df['Investors Name'].str.split(',')
df.set_index('Sr No',inplace=True)

# %%
df.rename(columns={'Date dd/mm/yyyy':'Date','City  Location':'City','InvestmentnType':'Investment Type'},inplace=True)

# %%
df.drop(columns=['Remarks'],inplace=True)

# %%
df['Amount in USD'].fillna('0',inplace=True)
# Out:
# C:\Users\shahi\AppData\Local\Temp\ipykernel_2572\1582066635.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Amount in USD'].fillna('0',inplace=True)

# %%
df['Amount in USD']=df['Amount in USD'].str.replace(',',"")
df['Amount in USD']=df['Amount in USD'].str.replace('undisclosed',"0")
df['Amount in USD']=df['Amount in USD'].str.replace('unknown',"0")
df['Amount in USD']=df['Amount in USD'].str.replace('Undisclosed',"0")

# df['Amount in USD'].astype(np.int32)

# %%
df=df[df['Amount in USD'].str.isdigit()]

# %%
df['Amount in USD']=df['Amount in USD'].astype('float')
# Out:
# C:\Users\shahi\AppData\Local\Temp\ipykernel_2572\493626883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Amount in USD']=df['Amount in USD'].astype('float')

# %%
# df['Amount in USD']=df['Amount in USD']*86

# %%
df
# Out:
#              Date                  Startup Name    Industry Vertical  \
# Sr No
# 1      09-01-2020                         BYJUS               E-Tech
# 2      13-01-2020                        Shuttl       Transportation
# 3      09-01-2020                     Mamaearth           E-commerce
# 4      02-01-2020  https://www.wealthbucket.in/              FinTech
# 5      02-01-2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29-01-2015                    Printvenue                  NaN
# 3041   29-01-2015                      Graphene                  NaN
# 3042   30-01-2015                Mad Street Den                  NaN
# 3043   30-01-2015                     Simplotel                  NaN
# 3044   31-01-2015              couponmachine.in                  NaN
#
#                                  SubVertical       City  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df.rename(columns={'Amount in USD':'amount'},inplace=True)
# Out:
# C:\Users\shahi\AppData\Local\Temp\ipykernel_2572\3345602226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Amount in USD':'amount'},inplace=True)

# %%
df
# Out:
#              Date                  Startup Name    Industry Vertical  \
# Sr No
# 1      09-01-2020                         BYJUS               E-Tech
# 2      13-01-2020                        Shuttl       Transportation
# 3      09-01-2020                     Mamaearth           E-commerce
# 4      02-01-2020  https://www.wealthbucket.in/              FinTech
# 5      02-01-2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29-01-2015                    Printvenue                  NaN
# 3041   29-01-2015                      Graphene                  NaN
# 3042   30-01-2015                Mad Street Den                  NaN
# 3043   30-01-2015                     Simplotel                  NaN
# 3044   31-01-2015              couponmachine.in                  NaN
#
#                                  SubVertical       City  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
def in_cr(dollar):
    inr=dollar*86
    return inr/10000000

df['amount']=df['amount'].apply(in_cr)
# Out:
# C:\Users\shahi\AppData\Local\Temp\ipykernel_2572\1410746591.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount']=df['amount'].apply(in_cr)

# %%
# df['Date']=df['Date'].str.replace('-','/')
df['Date']=df['Date'].str.replace('05/072018','05/07/2018')
df['Date']=pd.to_datetime(df['Date'],dayfirst=True,errors='coerce')
# Out:
# C:\Users\shahi\AppData\Local\Temp\ipykernel_2572\1208149948.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']=df['Date'].str.replace('05/072018','05/07/2018')
# C:\Users\shahi\AppData\Local\Temp\ipykernel_2572\1208149948.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']=pd.to_datetime(df['Date'],dayfirst=True,errors='coerce')

# %%
df['Date'].dt.month
# Out:
# Sr No
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# 5       1.0
#        ...
# 3040    1.0
# 3041    1.0
# 3042    1.0
# 3043    1.0
# 3044    1.0
# Name: Date, Length: 3039, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3039 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               3032 non-null   datetime64[ns]
#  1   Startup Name       3039 non-null   object
#  2   Industry Vertical  2868 non-null   object
#  3   SubVertical        2104 non-null   object
#  4   City               2859 non-null   object
#  5   Investors Name     3015 non-null   object
#  6   Investment Type    3037 non-null   object
#  7   amount             3039 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.7+ KB

# %%
df=df.dropna(subset=['Date','Startup Name','Industry Vertical','City','Investors Name','Investment Type','amount'])

# %%
df.to_csv('cleaned_startup./',index=False)

# %%
sorted(set(df['Investors Name'].str.split(',').sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
# ...

# %%
df[df['Investors Name'].str.contains('Sequoia Capital India')].sort_values('Date',ascending=False).head()[['Date','Startup Name','Industry Vertical','City','Investors Name','Investment Type','amount']]
# Out:
#             Date Startup Name  Industry Vertical       City  \
# Sr No
# 3     2020-01-09    Mamaearth         E-commerce  Bengaluru
# 69    2019-07-11       Moglix         E-Commerce  Singapore
# 150   2018-10-12    Blackbuck     Logistics Tech  Bengaluru
# 173   2018-08-08  Metro Bikes  Consumer Internet  Bengaluru
# 167   2018-08-02  Samosa Labs  Consumer Internet  Hyderabad
#
#                                           Investors Name  Investment Type  \
# Sr No
# 3                                  Sequoia Capital India         Series B
# 69     Composite Capital Management, Sequoia Capital ...         Series D
# 150                                Sequoia Capital India  Private Funding
# 173    Sequoia Capital India Advisors, Accel Partners...   Private Equity
# 167                     Xiaomi and Sequoia Capital India   Private Equity
#
#            amount
# Sr No
# 3      157.886196
# 69     516.000000
# 150    126.248000
# 173    104.920000
# 167     60.200000

# %%
df[df['Investors Name'].str.contains('Sequoia Capital India')].groupby('Startup Name')['amount'].sum().sort_values(ascending=False)
# Out:
# Startup Name
# Oyo Rooms      2150.000000
# OYO Rooms      2150.000000
# Dhruva          688.000000
# Moglix          516.000000
# FreshDesk       473.000000
# DailyHunt       215.000000
# Mamaearth       157.886196
# Blackbuck       126.248000
# Metro Bikes     104.920000
# HealthKart      103.200000
# Meesho           98.900000
# Unacademy        98.900000
# Belong           86.000000
# Samosa Labs      60.200000
# Faasos           54.180000
# OncoStem         51.600000
# Pocket Aces      25.800000
# CleverTap         0.000000
# Name: amount, dtype: float64

# %%
df[df['Investors Name'].str.contains('Tiger Global Management')].groupby('Industry Vertical')['amount'].sum().head().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df[df['Investors Name'].str.contains('Tiger Global Management')].groupby('City')['amount'].sum().head().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df['year']=df['Date'].dt.year
# Out:
# C:\Users\shahi\AppData\Local\Temp\ipykernel_2572\3002932815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year']=df['Date'].dt.year

# %%
df[df['Investors Name'].str.contains('Tiger Global Management')].groupby('year')['amount'].sum().plot()
# Out:
# <Axes: xlabel='year'>

# %%
df
# Out:
#             Date                  Startup Name           Industry Vertical  \
# Sr No
# 1     2020-01-09                         BYJUS                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-01-09                     Mamaearth                  E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/                     FinTech
# 5     2020-01-02                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  SubVertical       City  \
# ...

# %%
round(df['amount'].sum())
# Out:
# 309613

# %%
df.groupby('Startup Name')['amount'].max().sort_values(ascending=False).head(1).values[0]
# Out:
# 33540.0

# %%
round(df.groupby('Startup Name')['amount'].sum().mean(),2)
# Out:
# 134.97

# %%
df['Startup Name'].nunique()
# Out:
# 2294

# %%
df['Industry Vertical'].value_counts().head().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['month']=df['Date'].dt.month
# Out:
# C:\Users\shahi\AppData\Local\Temp\ipykernel_2572\2423553300.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month']=df['Date'].dt.month

# %%
temp_df=df.groupby(['year','month'])['amount'].count().reset_index()

# %%
temp_df['axis_X']=temp_df['month'].astype('str')+'-'+temp_df['year'].astype('str')

# %%
temp_df
# Out:
#     year  month  amount   axis_X
# 0   2015      4      61   4-2015
# 1   2015      5      55   5-2015
# 2   2015      6      84   6-2015
# 3   2015      7      95   7-2015
# 4   2015      8      98   8-2015
# 5   2015      9      87   9-2015
# 6   2015     10      93  10-2015
# 7   2015     11      90  11-2015
# 8   2015     12      88  12-2015
# 9   2016      1     104   1-2016
# 10  2016      2      99   2-2016
# 11  2016      3      84   3-2016
# 12  2016      4      77   4-2016
# 13  2016      5      79   5-2016
# 14  2016      6      97   6-2016
# 15  2016      7      63   7-2016
# 16  2016      8      87   8-2016
# 17  2016      9      73   9-2016
# 18  2016     10      80  10-2016
# 19  2016     11      72  11-2016
# 20  2016     12      72  12-2016
# 21  2017      1      72   1-2017
# 22  2017      2      48   2-2017
# 23  2017      3      71   3-2017
# 24  2017      4      71   4-2017
# 25  2017      5      67   5-2017
# 26  2017      6      65   6-2017
# ...

# %%
count=df.groupby(['year','month'])['amount'].count().reset_index()
count['axis_X']=count['month'].astype('str')+'-'+count['year'].astype('str')
count[['axis_X','amount']].plot()
# Out:
# <Axes: >

# %%
df=pd.read_csv('C:/Users/shahi/OneDrive/Desktop/Seminar/dashboard_stremlit/cleaned_startup.csv')
dff=pd.read_csv('C:/Users/shahi/OneDrive/Desktop/Seminar/dashboard_stremlit/startup_funding.csv')

# %%
df
# Out:
#             Date Startup Name       Industry Vertical  \
# 0     03-04-2015       Swiggy    Online Food Delivery
# 1     04-04-2015     Bluegape  Web Content Publishing
# 2     06-04-2015  InstaLively         Video Streaming
# 3     07-04-2015     LogiNext          Logistics Tech
# 4     07-04-2015    PressPlay    Travel Entertainment
# ...          ...          ...                     ...
# 2823  09-01-2020        BYJUS                  E-Tech
# 2824  09-01-2020    Mamaearth              E-commerce
# 2825  10-01-2020       Zomato             Hospitality
# 2826  13-01-2020        Pando               Logistics
# 2827  13-01-2020       Shuttl          Transportation
#
#                                    SubVertical       City  \
# 0                                          NaN  Bangalore
# 1                                          NaN    Gurgaon
# 2                                          NaN  New Delhi
# 3                                          NaN     Mumbai
# ...

# %%
df=df.query('amount != 0')

# %%
df.to_csv('Final_startup_data.csv')

# %%
df[df['Startup Name']=='Swiggy'].groupby('Investors Name')['amount'].sum().sort_values(ascending=False).head()
# Out:
# Investors Name
# Naspers                                                                                                      860.0
# Nasper, Accel India, SAIF Partners, Bessemer Venture Partners, Harmony Partners, Norwest Venture Partners    688.0
# Harmony Partners, RB Investments & existing investors                                                        301.0
# Norwest Venture Partners, SAIF Partners, Accel Partners                                                      141.9
# Bessemer Venture Partners                                                                                    129.0
# Name: amount, dtype: float64

# %%
test=list(df[df['Startup Name']=='Swiggy']['Industry Vertical'].values)

# %%
test
# Out:
# ['Online Food Delivery',
#  'Online Food Delivery',
#  'Online Food Ordering',
#  'Consumer Internet',
#  'Consumer Internet',
#  'Consumer Internet',
#  'Consumer Internet',
#  'Food and Beverages']

# %%
a=df[df['Industry Vertical'].isin(test)].groupby('Startup Name')['Industry Vertical'].value_counts().sort_values(ascending=False).head()

# %%
print(a)
len(test)
# Out:
# Startup Name  Industry Vertical
# Ola           Consumer Internet    7
# Medinfi       Consumer Internet    4
# Magicpin      Consumer Internet    4
# Swiggy        Consumer Internet    4
# BYJUS         Consumer Internet    3
# Name: count, dtype: int64
# 8

# %%
a.reset_index()['Startup Name']
# Out:
# 0          Fitpass
# 1     CollegeDekho
# 2            Fitso
# 3    Policy Bazaar
# 4     PolicyBazaar
# Name: Startup Name, dtype: object

# %%
a
# Out:
# Startup Name  amount
# Swiggy        129.00    2
# CollegeDekho  17.20     2
# Fitpass       8.60      2
# Fitso         1.72      2
# 1mg           86.00     1
# Name: count, dtype: int64

# %%
df=pd.read_csv('C:/Users/shahi/OneDrive/Desktop/Seminar/dashboard_stremlit/Final_startup_data.csv')

# %%
import plotly.graph_objects as go
big_inverst=df[df['Startup Name']=='Swiggy'].groupby('Date')['amount'].max().sort_values(ascending=False).head()
trace1=go.Line(x=big_inverst.index,y=big_inverst.values)
data=[trace1]
layout=go.Layout(title='')
fig=go.Figure(data,layout)
fig.show()
# Out:
# c:\Users\shahi\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\graph_objs\_deprecations.py:378: DeprecationWarning: plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
#
#   warnings.warn(

# %%
big_inverst
# Out:
# Date
# 07-02-2018    860.0
# 30-05-2017    688.0
# 19-01-2016    301.0
# 09-06-2015    141.9
# 06-05-2015    129.0
# Name: amount, dtype: float64

# %%
df[(df['Startup Name']=='Swiggy')& (df['Date']=='19-09-2016')]
# Out:
#      Unnamed: 0        Date Startup Name  Industry Vertical  \
# 942        1482  19-09-2016       Swiggy  Consumer Internet
#
#                          SubVertical       City             Investors Name  \
# 942  Online Food Ordering & Delivery  Bangalore  Bessemer Venture Partners
#
#     Investment Type  amount
# 942  Private Equity   129.0

# %%
df.iloc[942]
# Out:
# Unnamed: 0                                      1482
# Date                                      19-09-2016
# Startup Name                                  Swiggy
# Industry Vertical                  Consumer Internet
# SubVertical          Online Food Ordering & Delivery
# City                                       Bangalore
# Investors Name             Bessemer Venture Partners
# Investment Type                       Private Equity
# amount                                         129.0
# Name: 942, dtype: object

# %%
df['Date']=pd.to_datetime(df['Date'],dayfirst=True,errors='coerce')
df['month']=df['Date'].dt.month
df['year']=df['Date'].dt.year

# %%
df.groupby(['year','month'])['Startup Name'].count().reset_index()
# Out:
#     year  month  Startup Name
# 0   2015      4            50
# 1   2015      5            41
# 2   2015      6            56
# 3   2015      7            68
# 4   2015      8            65
# 5   2015      9            60
# 6   2015     10            59
# 7   2015     11            60
# 8   2015     12            54
# 9   2016      1            57
# 10  2016      2            56
# 11  2016      3            52
# 12  2016      4            38
# 13  2016      5            51
# 14  2016      6            54
# 15  2016      7            40
# 16  2016      8            56
# 17  2016      9            44
# 18  2016     10            50
# 19  2016     11            45
# 20  2016     12            41
# 21  2017      1            41
# 22  2017      2            35
# 23  2017      3            48
# 24  2017      4            47
# 25  2017      5            39
# 26  2017      6            48
# 27  2017      7            25
# 28  2017      8            26
# 29  2017      9            38
# ...

# %%
df.groupby(['year','month'])['amount'].count().reset_index()
# Out:
#     year  month  amount
# 0   2015      4      50
# 1   2015      5      41
# 2   2015      6      56
# 3   2015      7      68
# 4   2015      8      65
# 5   2015      9      60
# 6   2015     10      59
# 7   2015     11      60
# 8   2015     12      54
# 9   2016      1      57
# 10  2016      2      56
# 11  2016      3      52
# 12  2016      4      38
# 13  2016      5      51
# 14  2016      6      54
# 15  2016      7      40
# 16  2016      8      56
# 17  2016      9      44
# 18  2016     10      50
# 19  2016     11      45
# 20  2016     12      41
# 21  2017      1      41
# 22  2017      2      35
# 23  2017      3      48
# 24  2017      4      47
# 25  2017      5      39
# 26  2017      6      48
# 27  2017      7      25
# 28  2017      8      26
# 29  2017      9      38
# 30  2017     10      41
# 31  2017     11      33
# 32  2017     12      34
# 33  2018      1      31
# 34  2018      2      34
# 35  2018      3      28
# 36  2018      4      23
# ...

# %%
# top 5 startups
df.groupby('Startup Name')['amount'].sum().sort_values(ascending=False).head()
# Out:
# Startup Name
# Flipkart            34913.42
# Rapido Bike Taxi    33540.00
# Paytm               27080.97
# Ola                 17657.52
# Udaan                7482.00
# Name: amount, dtype: float64
